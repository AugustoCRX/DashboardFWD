# %%
import pandas as pd
import os
import numpy as np

# %%
main_path = os.getcwd().split('\\Projeto FWD')[0].capitalize() #confirma o diretório de instalação do script

# %%
df = pd.read_excel(fr"{main_path}\Projeto FWD\main files\19-AV. SANTOS DUMONT\Arquivos em excel\1-119920100023_EDECONSIL_FWD_PD_FX1 (1).xlsx", sheet_name= 'Table 1')

# %%
def checkColumnLines(df):
    for i in range(df.shape[1]):
        if pd.isnull(df.iloc[10][i]):
            df.iloc[10][i] = df.iloc[9][i]
        else:
            continue
checkColumnLines(df)

# %%
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0         NaN        NaN        NaN
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# 3         NaN        NaN        NaN
# 4         NaN        NaN        NaN
# ..        ...        ...        ...
# 69       2,34         43      4.364
# 70       2,38         42      4.262
# 71       2,42         42      4.273
# 72       2,46         46       4.66
# 73       2,50         47      4.833
#
#    LEVANTAMENTO DEFLECTOMÉTRICO com utilização do “Falling Weight Deflectometer” (FWD)\nModelo TBTFWD-NJ-MV  - DNER PRO 273/96  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 69                                                 22
# ...

# %%
df.columns[-2:]
# Out:
# Index(['DATA:', 'Unnamed: 17'], dtype='object')

# %%
#drop 0-9 lines and set them as columns
df.drop(index=[i for i in range(0,10)], inplace=True)
df.columns = df.iloc[0]
df.drop(index= 10, inplace=True)
df.reset_index(inplace=True)
df.drop(columns= df.columns[-2:], inplace=True)

# %%
df
# Out:
# 10  index    KM Target\nLoad kN Target\nLoad (Kgf)  D1  D2  D3  D4 D5 D6 D7  \
# 0      11  0,02              43              4.354  24  19  15  11  9  6  4
# 1      12  0,06              42              4.252  19  10   6   4  3  2  1
# 2      13  0,10              42              4.252  25  13   8   5  3  2  2
# 3      14  0,14              41               4.13  31  16  10   5  3  2  1
# 4      15  0,18              39              3.977  44  23  14   9  5  3  2
# ..    ...   ...             ...                ...  ..  ..  ..  .. .. .. ..
# 58     69  2,34              43              4.364  22  13   9   6  3  2  2
# 59     70  2,38              42              4.262  25  15  11   7  4  2  2
# 60     71  2,42              42              4.273  16   9   7   4  2  1  1
# 61     72  2,46              46               4.66  31  21  16  11  6  4  2
# 62     73  2,50              47              4.833  21  15  12   9  7  4  4
#
# ...

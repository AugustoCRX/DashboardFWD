# %%
import pandas as pd
import os
import numpy as np

# %%
main_path = os.getcwd().split('\\Projeto FWD')[0].capitalize() #confirma o diretório de instalação do script

# %%
df = pd.read_excel(fr"{main_path}\Projeto FWD\main files\19-AV. SANTOS DUMONT\Arquivos em excel\1-119920100023_EDECONSIL_FWD_PD_FX1 (1).xlsx", sheet_name= 'Table 1')

# %%
df.head(11)
# Out:
#       Unnamed: 0       Unnamed: 1          Unnamed: 2  \
# 0            NaN              NaN                 NaN
# 1            NaN              NaN                 NaN
# 2            NaN              NaN                 NaN
# 3            NaN              NaN                 NaN
# 4            NaN              NaN                 NaN
# 5       CLIENTE:              NaN                 NaN
# 6   OBRA/TRECHO:              NaN                 NaN
# 7         PISTA:              NaN                 NaN
# 8       SENTIDO:              NaN                 NaN
# 9             KM  Target\nLoad kN  Target\nLoad (Kgf)
# 10           NaN              NaN                 NaN
#
#    LEVANTAMENTO DEFLECTOMÉTRICO com utilização do “Falling Weight Deflectometer” (FWD)\nModelo TBTFWD-NJ-MV  - DNER PRO 273/96  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5               EDECONSIL CONSTRUÇÕES E LOCAÇÕES LTDA
# 6                                         SÃO LUIS/MA
# 7         AV. SANTOS DUMONT - PISTA DIREITA - FAIXA 1
# 8                                 AV. CASEMIRO JÚNIOR
# 9                     UNIDADE DAS LEITURAS (x10ˉ² mm)
# 10                                                 D1
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10         D2         D3         D4         D5         D6         D7
#
#    Unnamed: 10 Unnamed: 11  Unnamed: 12 Unnamed: 13 Unnamed: 14  Unnamed: 15  \
# 0          NaN         NaN          NaN         NaN         NaN          NaN
# 1          NaN         NaN          NaN         NaN         NaN          NaN
# 2          NaN         NaN          NaN         NaN         NaN          NaN
# 3          NaN         NaN          NaN         NaN         NaN          NaN
# 4          NaN         NaN          NaN         NaN         NaN          NaN
# 5          NaN         NaN          NaN         NaN         NaN          NaN
# 6          NaN         NaN          NaN         NaN         NaN          NaN
# 7          NaN         NaN          NaN         NaN         NaN          NaN
# 8          NaN         NaN          NaN         NaN         NaN          NaN
# 9    Temp (ºC)         NaN  Coordenadas         NaN        RAIO  Data e Hora
# 10          Ar        Pav.     Latitude   Longitude         NaN          NaN
#
#                   DATA: Unnamed: 17
# 0   2023-08-18 00:00:00         NaN
# 1         RELATÓRIO N°:         NaN
# 2         1199-00000/23         NaN
# 3                OS Nº:         NaN
# 4               1199/23         NaN
# 5                   NaN         NaN
# 6                   NaN         NaN
# 7                   NaN         NaN
# 8                   NaN         NaN
# 9                   NaN        Obs.
# 10                  NaN         NaN

# %%
for i in range(df.shape[1]):
    if df.iloc[10][i] == np.nan:

# %%
columns = df.iloc[9]
